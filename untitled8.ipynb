# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshithaNampalli/23CSBTB29/blob/main/untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Decision Tree Classifier Building in Scikit-***learn*** ***`[bold text](https://)`***

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %% [markdown]
# ## **Loading Data**

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
# load dataset
pima = pd.read_csv("diabetes.csv", header=None, names=col_names)

# %%
pima.head()
# Out:
#       pregnant  glucose             bp           skin  insulin   bmi  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#                    pedigree  age    label
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0

# %% [markdown]
# # Feature Selection

# %%
#split dataset in features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = pima[feature_cols] # Features
y = pima.label # Target variable

# %% [markdown]
# Splitting Data

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %% [markdown]
# Building Decision Tree Model

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# Load the dataset with specified column names
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
pima = pd.read_csv("diabetes.csv", header=0, names=col_names)

# Display the first few rows of the dataset
pima.head()

# Define features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age', 'glucose', 'bp', 'pedigree']
X = pima[feature_cols]  # Features
y = pima.label  # Target variable

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)  # 70% training and 30% test

# Initialize and train a Logistic Regression model
# You can replace this with any other classifier of your choice
logreg = LogisticRegression(max_iter=1000) # increasing max_iter to ensure convergence
logreg.fit(X_train, y_train)
# Predict on the test set
y_pred = logreg.predict(X_test)

# Evaluate model accuracy
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7835497835497836

# %% [markdown]
# # Evaluating the **Model**

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7835497835497836

# %%
Accuracy: 0.6753246753246753

# %% [markdown]
# Visualizing Decision Trees

# %%
from sklearn.tree import export_graphviz
#from sklearn.externals.six import StringIO  # Deprecated, use io.StringIO instead
from io import StringIO
from IPython.display import Image
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
                                #The following lines were unnecessarily indented, causing the error. Corrected indentation:
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('diabetes.png')
Image(graph.create_png())

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7705627705627706
